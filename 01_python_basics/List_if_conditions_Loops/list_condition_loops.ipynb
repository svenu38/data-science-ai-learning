# %% [markdown]
# # Python List,if conditions and for loop — Data Science Roadmap

# %% [markdown]
# suppose you will go to the market to buy a groceries

# %%
item1= "bread"
item2= "milk"
item3= "eggs"
item4= "butter"

# %% [markdown]
# usully after buying everything you will keep it all into you bag , here bag is nothing but the List
#
# list can store n number of values inside it

# %%
items= [item1, item2, item3, item4] # items is a list containing all the items
print(items)
# Out:
# ['bread', 'milk', 'eggs', 'butter']

# %% [markdown]
# A list in Python is an ordered, changeable (mutable) collection of items.
# A list can store multiple values in a single variable — numbers, strings, or even mixed data types.

# %% [markdown]
# ### 🔹 Features of Python Lists
#
# | **Feature**         | **Explanation**                                      |
# |---------------------|------------------------------------------------------|
# | **Ordered**         | Items have a fixed position (index).                 |
# | **Mutable**         | You can change, add, or remove items.                |
# | **Allows duplicates** | Same value can appear multiple times.              |
# | **Heterogeneous**   | Supports different data types (int, str, float, etc.) |

# %%
item1[0] # Accessing first character of item1
# Out:
# 'b'

# %%
items[0] # Accessing first item from the list
# Out:
# 'bread'

# %%
items[0:3] # Slicing first three items from the list
# Out:
# ['bread', 'milk', 'eggs']

# %%
items[0:3:2]
# Out:
# ['bread', 'eggs']

# %%
items[0][1] # Accessing second character of first item in the list
# Out:
# 'r'

# %%
items[0][-1] # Accessing last character of first item in the list
# Out:
# 'd'

# %%
items.insert(3,list("drinks")) # Inserting a new list at index 3

# %%
print(items)
# Out:
# ['bread', 'milk', 'eggs', ['d', 'r', 'i', 'n', 'k', 's'], 'butter']

# %%
'bread' in items # Checking if 'bread' is in items list
# Out:
# True

# %%
'cheese' in items # Checking if 'cheese' is in items list
# Out:
# False

# %%
expenses = [2200, 2350, 2600, 2130, 2190]

# %%
sum(expenses)
# Out:
# 11470

# %%
cooking_items = ['pasta', 'tomato sauce', 'onions', 'garlic']
drinking_items = ['water', 'coffee', 'tea']

# %%
all_items = cooking_items + drinking_items

# %%
print(all_items)
# Out:
# ['pasta', 'tomato sauce', 'onions', 'garlic', 'water', 'coffee', 'tea']

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
print(all_items)
# Out:
# ['tea', 'coffee', 'water', 'garlic', 'onions', 'tomato sauce', 'pasta']

# %%
all_items.reverse()

# %%
all_items
# Out:
# ['pasta', 'tomato sauce', 'onions', 'garlic', 'water', 'coffee', 'tea']

# %%
random=['salt',5,3.5,True]

# %%
random # homogeneous list , it can contain different data types
# Out:
# ['salt', 5, 3.5, True]
